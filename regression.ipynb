# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model

# %%
# split data target and features
X = df.drop('mnth', axis=1)
y = df.mnth
X
# Out:
#        instant      dteday  season  yr  hr  holiday  weekday  workingday  \
# 0            1   1.01.2011       1   0   0        0        6           0
# 1            2   1.01.2011       1   0   1        0        6           0
# 2            3   1.01.2011       1   0   2        0        6           0
# 3            4   1.01.2011       1   0   3        0        6           0
# 4            5   1.01.2011       1   0   4        0        6           0
# 5            6   1.01.2011       1   0   5        0        6           0
# 6            7   1.01.2011       1   0   6        0        6           0
# 7            8   1.01.2011       1   0   7        0        6           0
# 8            9   1.01.2011       1   0   8        0        6           0
# 9           10   1.01.2011       1   0   9        0        6           0
# 10          11   1.01.2011       1   0  10        0        6           0
# 11          12   1.01.2011       1   0  11        0        6           0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
# Load the bike dataset
df = pd.read_csv("hour.csv",sep=";")
df.head(10)
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  1.01.2011       1   0     1   0        0        6           0
# 1        2  1.01.2011       1   0     1   1        0        6           0
# 2        3  1.01.2011       1   0     1   2        0        6           0
# 3        4  1.01.2011       1   0     1   3        0        6           0
# 4        5  1.01.2011       1   0     1   4        0        6           0
# 5        6  1.01.2011       1   0     1   5        0        6           0
# 6        7  1.01.2011       1   0     1   6        0        6           0
# 7        8  1.01.2011       1   0     1   7        0        6           0
# 8        9  1.01.2011       1   0     1   8        0        6           0
# 9       10  1.01.2011       1   0     1   9        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81     0.0000       3          13   16
# ...

# %%
# Create linear regression object and fit model
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-94e502987497> in <module>
#       1 # Create linear regression object and fit model
#       2 reg = LinearRegression()
# ----> 3 reg.fit(X_train, y_train)
#
# c:\users\cansu kaplan\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
reg.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-16-aaacfc6de2d2> in <module>
# ----> 1 reg.score(X_test, y_test)
#
# c:\users\cansu kaplan\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     406         from .metrics import r2_score
#     407         from .metrics.regression import _check_reg_targets
# --> 408         y_pred = self.predict(X)
#     409         # XXX: Remove the check in 0.23
#     410         y_type, _, _, _ = _check_reg_targets(y, y_pred, None)
#
# c:\users\cansu kaplan\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     219             Returns predicted values.
#     220         """
# --> 221         return self._decision_function(X)
#     222
#     223     _preprocess_data = staticmethod(_preprocess_data)
#
# ...

# %%
predicted = reg.predict(X_test)
predicted
# Out:
# array([  7.,   5., 743., ...,   3., 606.,  16.])

# %%
result = pd.DataFrame(columns=['target', 'predicted'])
result.target = y_test
result.predicted = predicted

# %%
result.head(10)
# Out:
#        target  predicted
# 3439        7        7.0
# 6542        5        5.0
# 15470     743      743.0
# 9851      208      208.0
# 12640     333      333.0
# 1427      187      187.0
# 15888     124      124.0
# 14772     925      925.0
# 15725     212      212.0
# 1057      161      161.0

# %%
mean_absolute_error(result.target, result.predicted)
# Out:
# 2.3414743962370654e-11
